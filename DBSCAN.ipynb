# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh230305/Data_Science/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.cluster import DBSCAN

# %%
X, y=make_moons(n_samples=200, noise=0.2, random_state=42)
df=pd.DataFrame(X,columns=["Feature1","Feature2"])
df
# Out:
#      Feature1  Feature2
# 0   -1.106897  0.042293
# 1    0.956800  0.456750
# 2    0.733516  0.584617
# 3    1.111407 -0.309214
# 4    0.209082  0.000657
# ..        ...       ...
# 195 -0.058311  0.228059
# 196  0.737210  0.320761
# 197 -1.475982  0.357239
# 198  1.883321 -0.109890
# 199  0.049478  0.491292
#
# [200 rows x 2 columns]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(X)

# %%
clustering_DB=DBSCAN(eps=0.5,min_samples=5)
DB_labels=clustering_DB.fit_predict(x_scaled)
df['clusters']=DB_labels

# %%
sns.scatterplot(x=df['Feature1'],y=df['Feature2'],hue=df['clusters'],palette='tab10')
# Out:
# <Axes: xlabel='Feature1', ylabel='Feature2'>
